# %%
import json
import os

# %%
government = 'hoekschewaard'
BASE_PATH = f"/Volumes/Samsung_T5/data/{government}/vergaderingen"

# %%
def load_transcript(path):
    with open(path, "r") as f:
        data = json.load(f)

    data = [
        {
            "start": l["start"],
            "end": l["end"],
            "text": l["text"].replace("...", "").strip(),
        }
        for l in data["segments"]
    ]

    return data


def load_diorizations(path):
    with open(path, "r") as f:
        lines = f.readlines()
        data = [
            {"start": float(rttm[3]), "duration": float(rttm[4]), "speaker": rttm[7]}
            for rttm in [line.strip().split(" ") for line in lines]
        ]

    return data

# %%
def create_speaking_turns(diorizations):
    current_speaker = ""
    current_speaker_start = 0
    current_speaker_duration = 0

    speaking_turns = []

    for i, dior in enumerate(diorizations):
        # If speaker speaks for less than a few seconds, and they do not keep speaking,
        # it is probably a diorization error and we discard it.
        if (
            i < len(diorizations) - 2
            and dior["duration"] < 1
            and dior["speaker"] != diorizations[i + 1]["speaker"]
        ):
            current_speaker_duration = (
                dior["start"] + dior["duration"] - current_speaker_start
            )
            continue
        if dior["speaker"] == current_speaker:
            current_speaker_duration = (
                dior["start"] + dior["duration"] - current_speaker_start
            )
        else:
            # TODO: handle
            if i != 0:
                speaking_turns.append(
                    {
                        "speaker": current_speaker,
                        "start": round(current_speaker_start, 2),
                        "duration": round(current_speaker_duration, 2),
                    }
                )

            current_speaker = dior["speaker"]
            current_speaker_start = dior["start"]
            current_speaker_duration = dior["duration"]

    return speaking_turns

# %%
def create_speakers_text(
    speaking_turns, transcript, code, year, government, meeting_type
):
    speakers_text = []
    current_speaker_text = ""
    for speaker in speaking_turns:
        speaker_start = round(speaker["start"], 2)
        speaker_end = round(speaker["start"] + speaker["duration"], 2)
        for i, sentence in enumerate(transcript):
            # If the end of the sentence is further than the speaker's end,
            # speaker is done with talking and his text is added to the list.
            if sentence["start"] < speaker["start"]:
                continue
            if sentence["end"] > speaker_end - 3:
                if current_speaker_text != "":
                    # Prevents some sentences from not being caught due to beginnen
                    # and end rounding errors.
                    if i < len(transcript) - 2:
                        current_speaker_text += (
                            transcript[i + 1]["text"] + transcript[i + 2]["text"]
                        )
                    speakers_text.append(
                        {
                            "text": current_speaker_text,
                            "start": speaker_start,
                            "end": speaker_end,
                            "code": code,
                            "year": year,
                            "government": government,
                            "type": meeting_type,
                            "speaker": speaker["speaker"],
                        }
                    )
                current_speaker_text = ""
                break
            else:
                current_speaker_text += sentence["text"]

    return speakers_text

# %%
def insert_no_speaks(speakers_text):
    speakers_text_with_no_speaks = []
    prev_end = 0
    for speaker in speakers_text:
        curr_start = speaker["start"]
        if curr_start > prev_end:
            speakers_text_with_no_speaks.append(
                {
                    "text": "",
                    "start": prev_end,
                    "end": curr_start,
                    "code": code,
                    "year": year,
                    "government": government,
                    "type": meeting_type,
                    "speaker": "",
                }
            )
            speakers_text_with_no_speaks.append(speaker)

        prev_end = speaker["end"]

    return speakers_text_with_no_speaks

# %%
meeting_type = "vergadering"
for year in os.listdir(BASE_PATH):
    if year == ".DS_Store":
        continue
    if not os.path.isdir(f"{BASE_PATH}/{year}/transcripts") or not os.path.isdir(
        f"{BASE_PATH}/{year}/diorizations"
    ):
        continue

    save_dir = f"{BASE_PATH}/{year}/turnObjects"
    if not os.path.isdir(save_dir):
        os.mkdir(save_dir)

    for transcript_file in os.listdir(f"{BASE_PATH}/{year}/transcripts"):
        if transcript_file.startswith("."):
            continue
        if os.path.isfile(f"{save_dir}/{transcript_file}"):
            print(f"{save_dir}/{transcript_file} already exists")
            continue
        code = transcript_file.split(".")[0]
        if not os.path.isfile(f"{BASE_PATH}/{year}/diorizations/{code}.wav.rttm"):
            print(f"diorization file for {code} not found.")
            continue

        diorizations = load_diorizations(
            f"{BASE_PATH}/{year}/diorizations/{code}.wav.rttm"
        )

        print(f"Doing {BASE_PATH}/{year}/transcripts/{transcript_file}")
        try:
            transcript = load_transcript(
                f"{BASE_PATH}/{year}/transcripts/{transcript_file}"
            )
        except Exception:
            continue
        speaking_turns = create_speaking_turns(diorizations)

        speakers_text = create_speakers_text(
            speaking_turns, transcript, code, year, government, meeting_type
        )

        speakers_text_nospeaks = insert_no_speaks(speakers_text)

        with open(f"{save_dir}/{transcript_file}", "w") as f:
            json.dump(speakers_text_nospeaks, f)
# Out:
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2019/turnObjects/586219.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2019/turnObjects/586232.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2019/turnObjects/586242.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2019/turnObjects/586238.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2019/turnObjects/586215.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2019/turnObjects/657080.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2019/turnObjects/586231.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2019/turnObjects/586224.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2019/turnObjects/586241.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2019/turnObjects/598036.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2019/turnObjects/586227.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2019/turnObjects/690521.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2019/turnObjects/586216.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2019/turnObjects/586237.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2019/turnObjects/598031.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2019/turnObjects/586235.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2019/turnObjects/636280.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2019/turnObjects/668722.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2019/turnObjects/586217.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2019/turnObjects/586243.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2019/turnObjects/586236.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2019/turnObjects/586244.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2019/turnObjects/586239.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2019/turnObjects/674257.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2019/turnObjects/586228.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2020/turnObjects/760192.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2020/turnObjects/760197.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2020/turnObjects/743807.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2020/turnObjects/763769.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2020/turnObjects/760189.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2020/turnObjects/760202.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2020/turnObjects/729315.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2020/turnObjects/763895.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2020/turnObjects/760199.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2020/turnObjects/760183.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2020/turnObjects/736817.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2020/turnObjects/730739.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2020/turnObjects/744242.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2020/turnObjects/725788.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2020/turnObjects/696757.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2020/turnObjects/724234.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2020/turnObjects/760212.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2020/turnObjects/725786.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2020/turnObjects/699486.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2020/turnObjects/760184.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2020/turnObjects/776835.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2020/turnObjects/724242.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2020/turnObjects/696758.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2020/turnObjects/730068.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2020/turnObjects/716404.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2020/turnObjects/724240.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2020/turnObjects/760193.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2020/turnObjects/760191.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2020/turnObjects/743803.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2020/turnObjects/760178.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2020/turnObjects/760210.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2020/turnObjects/696759.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2020/turnObjects/729210.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2020/turnObjects/760181.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2020/turnObjects/770582.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2020/turnObjects/784019.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2020/turnObjects/724238.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2020/turnObjects/784653.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2020/turnObjects/725784.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2020/turnObjects/696760.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2021/turnObjects/833613.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2021/turnObjects/833577.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2021/turnObjects/803295.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2021/turnObjects/833634.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2021/turnObjects/831226.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2021/turnObjects/833567.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2021/turnObjects/833566.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2021/turnObjects/831225.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2021/turnObjects/833629.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2021/turnObjects/821299.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2021/turnObjects/831240.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2021/turnObjects/831237.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2021/turnObjects/854853.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2021/turnObjects/833563.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2021/turnObjects/833617.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2021/turnObjects/821292.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2021/turnObjects/803289.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2021/turnObjects/833575.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2021/turnObjects/845563.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2021/turnObjects/833539.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2021/turnObjects/821307.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2021/turnObjects/833588.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2021/turnObjects/821314.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2021/turnObjects/831228.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2021/turnObjects/845529.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2021/turnObjects/833578.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2021/turnObjects/864625.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2021/turnObjects/845525.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2021/turnObjects/833622.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2021/turnObjects/833544.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2021/turnObjects/845564.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2021/turnObjects/833627.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2021/turnObjects/833569.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2021/turnObjects/833571.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2021/turnObjects/831239.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2021/turnObjects/833581.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2021/turnObjects/833612.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2021/turnObjects/833587.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2021/turnObjects/831243.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2021/turnObjects/833625.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2021/turnObjects/831229.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2021/turnObjects/845528.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2021/turnObjects/833598.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2021/turnObjects/831241.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2021/turnObjects/803298.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2021/turnObjects/833565.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2021/turnObjects/831227.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2021/turnObjects/912555.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2021/turnObjects/821310.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2021/turnObjects/833606.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2021/turnObjects/803290.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2021/turnObjects/833556.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2021/turnObjects/833616.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2021/turnObjects/833572.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2021/turnObjects/833576.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2021/turnObjects/882459.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2021/turnObjects/911699.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2021/turnObjects/803294.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2022/turnObjects/919796.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2022/turnObjects/919591.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2022/turnObjects/919805.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2022/turnObjects/919584.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2022/turnObjects/919565.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2022/turnObjects/919873.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2022/turnObjects/919880.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2022/turnObjects/919824.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2022/turnObjects/1061302.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2022/turnObjects/919765.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2022/turnObjects/919833.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2022/turnObjects/919874.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2022/turnObjects/1058226.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2022/turnObjects/919572.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2022/turnObjects/950299.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2022/turnObjects/1054861.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2022/turnObjects/919531.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2022/turnObjects/919545.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2022/turnObjects/919825.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2022/turnObjects/919518.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2022/turnObjects/977741.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2022/turnObjects/919769.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2022/turnObjects/919886.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2022/turnObjects/919792.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2022/turnObjects/919832.mp4.json already exists
# Doing /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2022/transcripts/919891.mp4.json
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2022/turnObjects/919781.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2022/turnObjects/919830.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2022/turnObjects/919603.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2022/turnObjects/919809.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2022/turnObjects/919803.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2022/turnObjects/919774.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2022/turnObjects/919843.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2022/turnObjects/919847.mp4.json already exists
# Doing /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2022/transcripts/919594.mp4.json
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2022/turnObjects/919870.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2022/turnObjects/919541.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2022/turnObjects/962912.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2022/turnObjects/919846.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2022/turnObjects/919589.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2022/turnObjects/919845.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2022/turnObjects/919779.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2022/turnObjects/970226.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2022/turnObjects/919602.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2022/turnObjects/919587.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2022/turnObjects/989110.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2022/turnObjects/919581.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2022/turnObjects/993571.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2022/turnObjects/919865.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2022/turnObjects/953476.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2023/turnObjects/1068448.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2023/turnObjects/1160027.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2023/turnObjects/1068485.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2023/turnObjects/1068618.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2023/turnObjects/1068470.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2023/turnObjects/1068482.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2023/turnObjects/1064226.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2023/turnObjects/1068505.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2023/turnObjects/1087752.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2023/turnObjects/1068603.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2023/turnObjects/1068473.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2023/turnObjects/1068512.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2023/turnObjects/1068624.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2023/turnObjects/1068453.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2023/turnObjects/1068570.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2023/turnObjects/1068487.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2023/turnObjects/1068571.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2023/turnObjects/1068594.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2023/turnObjects/1068492.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2023/turnObjects/1068520.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2023/turnObjects/1068617.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2023/turnObjects/1068519.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2023/turnObjects/1065017.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2023/turnObjects/1068479.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2023/turnObjects/1068488.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2023/turnObjects/1068451.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2023/turnObjects/1068508.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2023/turnObjects/1109657.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2023/turnObjects/1068541.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2023/turnObjects/1068522.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2023/turnObjects/1068534.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2023/turnObjects/1068525.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2023/turnObjects/1068601.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2023/turnObjects/1068538.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2023/turnObjects/1068543.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2023/turnObjects/1119491.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2023/turnObjects/1068528.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2023/turnObjects/1068529.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2023/turnObjects/1068539.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2023/turnObjects/1154482.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2023/turnObjects/1068506.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2023/turnObjects/1068517.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2023/turnObjects/1068621.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2023/turnObjects/1109653.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2023/turnObjects/1068478.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2023/turnObjects/1068531.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2023/turnObjects/1068489.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2023/turnObjects/1068535.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2023/turnObjects/1116762.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2023/turnObjects/1068481.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2023/turnObjects/1068441.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2023/turnObjects/1160213.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2023/turnObjects/1068491.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2023/turnObjects/1068510.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2023/turnObjects/1068472.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2023/turnObjects/1068469.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2023/turnObjects/1068511.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2023/turnObjects/1068475.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2023/turnObjects/1068530.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2023/turnObjects/1068620.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2023/turnObjects/1068443.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2024/turnObjects/1178233.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2024/turnObjects/1178272.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2024/turnObjects/1178236.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2024/turnObjects/1178238.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2024/turnObjects/1178270.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2024/turnObjects/1200221.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2024/turnObjects/1178273.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2024/turnObjects/1192781.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2024/turnObjects/1178279.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2024/turnObjects/1178249.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2024/turnObjects/1178262.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2024/turnObjects/1178278.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2024/turnObjects/1178281.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2024/turnObjects/1178261.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2024/turnObjects/1178275.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2024/turnObjects/1178276.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2024/turnObjects/1178269.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2024/turnObjects/1178235.mp4.json already exists
# /Volumes/Samsung_T5/data/hoekschewaard/vergaderingen/2024/turnObjects/1178255.mp4.json already exists
