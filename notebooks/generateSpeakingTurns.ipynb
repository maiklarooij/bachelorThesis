# %%
import json
import os

# %%
government = 'haarlem'
BASE_PATH = f"data/{government}"

# %%
def load_transcript(path):
    with open(path, "r") as f:
        data = json.load(f)

    data = [{"start": l["start"], "end": l["end"], "text": l["text"].replace("...", "").strip()} for l in data["segments"]]

    return data


def load_diorizations(path):
    with open(path, "r") as f:
        lines = f.readlines()
        data = [
            {"start": float(rttm[3]), "duration": float(rttm[4]), "speaker": rttm[7]}
            for rttm in [line.strip().split(" ") for line in lines]
        ]

    return data

# %%
def create_speaking_turns(diorizations):
    current_speaker = ""
    current_speaker_start = 0
    current_speaker_duration = 0

    speaking_turns = []

    for i, dior in enumerate(diorizations):
        # If speaker speaks for less than a few seconds, and they do not keep speaking,
        # it is probably a diorization error and we discard it.
        if (
            i < len(diorizations) - 2
            and dior["duration"] < 1
            and dior["speaker"] != diorizations[i + 1]["speaker"]
        ):
            current_speaker_duration = (
                dior["start"] + dior["duration"] - current_speaker_start
            )
            continue
        if dior["speaker"] == current_speaker:
            current_speaker_duration = (
                dior["start"] + dior["duration"] - current_speaker_start
            )
        else:
            # TODO: handle
            if i != 0:
                speaking_turns.append(
                    {
                        "speaker": current_speaker,
                        "start": round(current_speaker_start, 2),
                        "duration": round(current_speaker_duration, 2),
                    }
                )

            current_speaker = dior["speaker"]
            current_speaker_start = dior["start"]
            current_speaker_duration = dior["duration"]

    return speaking_turns

# %%
def create_speakers_text(speaking_turns, transcript, code, year, government):
    speakers_text = []
    current_speaker_text = ""
    for speaker in speaking_turns:
        speaker_start = round(speaker["start"], 2)
        speaker_end = round(speaker["start"] + speaker["duration"], 2)
        for i, sentence in enumerate(transcript):
            # If the end of the sentence is further than the speaker's end,
            # speaker is done with talking and his text is added to the list.
            if sentence["start"] < speaker["start"]:
                continue
            if sentence["end"] > speaker_end - 3:
                if current_speaker_text != "":
                    # Prevents some sentences from not being caught due to beginnen
                    # and end rounding errors.
                    if i < len(transcript) - 2:
                        current_speaker_text += (
                            transcript[i + 1]["text"] + transcript[i + 2]["text"]
                        )
                    speakers_text.append(
                        {
                            "text": current_speaker_text,
                            "start": speaker_start,
                            "end": speaker_end,
                            "code": code,
                            "year": year,
                            "government": government,
                        }
                    )
                current_speaker_text = ""
                break
            else:
                current_speaker_text += sentence["text"]

    return speakers_text

# %%
for year in os.listdir(BASE_PATH):
    if year == ".DS_Store":
        continue
    if not os.path.isdir(f"{BASE_PATH}/{year}/transcripts") or not os.path.isdir(
        f"{BASE_PATH}/{year}/diorizations"
    ):
        continue

    save_dir = f"{BASE_PATH}/{year}/turnObjects"
    if not os.path.isdir(save_dir):
        os.mkdir(save_dir)

    for transcript_file in os.listdir(f"{BASE_PATH}/{year}/transcripts"):
        code = transcript_file.split(".")[0]
        if not os.path.isfile(f"{BASE_PATH}/{year}/diorizations/{code}.wav.rttm"):
            print(f"diorization file for {code} not found.")
            continue

        diorizations = load_diorizations(
            f"{BASE_PATH}/{year}/diorizations/{code}.wav.rttm"
        )

        print(f"Doing {BASE_PATH}/{year}/transcripts/{transcript_file}")
        transcript = load_transcript(
            f"{BASE_PATH}/{year}/transcripts/{transcript_file}"
        )

        speaking_turns = create_speaking_turns(diorizations)

        speakers_text = create_speakers_text(
            speaking_turns, transcript, code, year, government
        )

        with open(f"{save_dir}/{transcript_file}", "w") as f:
            json.dump(speakers_text, f)
# Out:
# Doing data/haarlem/2014/transcripts/125416.mp4.json
# Doing data/haarlem/2014/transcripts/103253.mp4.json
# Doing data/haarlem/2014/transcripts/101050.mp4.json
# Doing data/haarlem/2014/transcripts/101051.mp4.json
# diorization file for  not found.
# Doing data/haarlem/2014/transcripts/101057.mp4.json
# Doing data/haarlem/2014/transcripts/101041.mp4.json
# Doing data/haarlem/2014/transcripts/101037.mp4.json
# Doing data/haarlem/2014/transcripts/101663.mp4.json
# Doing data/haarlem/2014/transcripts/101058.mp4.json
# Doing data/haarlem/2014/transcripts/101039.mp4.json
# Doing data/haarlem/2014/transcripts/101044.mp4.json
# Doing data/haarlem/2014/transcripts/101045.mp4.json
# Doing data/haarlem/2014/transcripts/101048.mp4.json
# Doing data/haarlem/2014/transcripts/101043.mp4.json
# Doing data/haarlem/2014/transcripts/101042.mp4.json
# Doing data/haarlem/2014/transcripts/148629.mp4.json
# Doing data/haarlem/2022/transcripts/938922.mp4.json
# Doing data/haarlem/2022/transcripts/938863.mp4.json
# Doing data/haarlem/2022/transcripts/973142.mp4.json
# Doing data/haarlem/2022/transcripts/938929.mp4.json
# Doing data/haarlem/2022/transcripts/938928.mp4.json
# Doing data/haarlem/2022/transcripts/938856.mp4.json
# Doing data/haarlem/2022/transcripts/938857.mp4.json
# Doing data/haarlem/2022/transcripts/1043872.mp4.json
# Doing data/haarlem/2022/transcripts/957952.mp4.json
# Doing data/haarlem/2022/transcripts/938875.mp4.json
# Doing data/haarlem/2022/transcripts/938874.mp4.json
# Doing data/haarlem/2022/transcripts/938934.mp4.json
# diorization file for  not found.
# Doing data/haarlem/2022/transcripts/938935.mp4.json
# Doing data/haarlem/2022/transcripts/1031210.mp4.json
# Doing data/haarlem/2022/transcripts/938836.mp4.json
# Doing data/haarlem/2022/transcripts/948780.mp4.json
# Doing data/haarlem/2022/transcripts/981328.mp4.json
# Doing data/haarlem/2022/transcripts/938873.mp4.json
# Doing data/haarlem/2022/transcripts/938932.mp4.json
# Doing data/haarlem/2022/transcripts/951774.mp4.json
# Doing data/haarlem/2022/transcripts/995469.mp4.json
# Doing data/haarlem/2022/transcripts/1064569.mp4.json
# Doing data/haarlem/2022/transcripts/961049.mp4.json
# Doing data/haarlem/2022/transcripts/1049453.mp4.json
# Doing data/haarlem/2022/transcripts/938831.mp4.json
# Doing data/haarlem/2022/transcripts/938830.mp4.json
# Doing data/haarlem/2022/transcripts/938878.mp4.json
# Doing data/haarlem/2022/transcripts/938879.mp4.json
# Doing data/haarlem/2022/transcripts/990577.mp4.json
# Doing data/haarlem/2021/transcripts/847790.mp4.json
# Doing data/haarlem/2021/transcripts/818793.mp4.json
# Doing data/haarlem/2021/transcripts/818608.mp4.json
# Doing data/haarlem/2021/transcripts/832013.mp4.json
# Doing data/haarlem/2021/transcripts/819106.mp4.json
# Doing data/haarlem/2021/transcripts/819107.mp4.json
# Doing data/haarlem/2021/transcripts/913894.mp4.json
# Doing data/haarlem/2021/transcripts/821862.mp4.json
# Doing data/haarlem/2021/transcripts/818588.mp4.json
# Doing data/haarlem/2021/transcripts/930329.mp4.json
# Doing data/haarlem/2021/transcripts/851021.mp4.json
# Doing data/haarlem/2021/transcripts/908448.mp4.json
# Doing data/haarlem/2021/transcripts/818806.mp4.json
# Doing data/haarlem/2021/transcripts/861303.mp4.json
# Doing data/haarlem/2021/transcripts/876841.mp4.json
# Doing data/haarlem/2020/transcripts/800767.mp4.json
# Doing data/haarlem/2020/transcripts/730229.mp4.json
# Doing data/haarlem/2020/transcripts/764351.mp4.json
# Doing data/haarlem/2020/transcripts/745507.mp4.json
# Doing data/haarlem/2020/transcripts/706573.mp4.json
# Doing data/haarlem/2020/transcripts/730691.mp4.json
# Doing data/haarlem/2020/transcripts/713349.mp4.json
# Doing data/haarlem/2020/transcripts/764381.mp4.json
# Doing data/haarlem/2020/transcripts/706578.mp4.json
# Doing data/haarlem/2020/transcripts/742074.mp4.json
# Doing data/haarlem/2020/transcripts/706512.mp4.json
# Doing data/haarlem/2020/transcripts/706581.mp4.json
# Doing data/haarlem/2020/transcripts/764346.mp4.json
# diorization file for  not found.
# Doing data/haarlem/2020/transcripts/728328.mp4.json
# Doing data/haarlem/2020/transcripts/760633.mp4.json
# Doing data/haarlem/2020/transcripts/738846.mp4.json
# Doing data/haarlem/2020/transcripts/706565.mp4.json
# Doing data/haarlem/2020/transcripts/706564.mp4.json
# Doing data/haarlem/2020/transcripts/721132.mp4.json
# Doing data/haarlem/2020/transcripts/741433.mp4.json
# Doing data/haarlem/2020/transcripts/780852.mp4.json
# Doing data/haarlem/2020/transcripts/706515.mp4.json
# Doing data/haarlem/2020/transcripts/730238.mp4.json
# Doing data/haarlem/2020/transcripts/730239.mp4.json
# Doing data/haarlem/2020/transcripts/706563.mp4.json
# Doing data/haarlem/2020/transcripts/706485.mp4.json
# Doing data/haarlem/2020/transcripts/706568.mp4.json
# Doing data/haarlem/2020/transcripts/706591.mp4.json
# Doing data/haarlem/2020/transcripts/764357.mp4.json
# Doing data/haarlem/2020/transcripts/706492.mp4.json
# Doing data/haarlem/2020/transcripts/706540.mp4.json
# Doing data/haarlem/2020/transcripts/706552.mp4.json
# Doing data/haarlem/2020/transcripts/706589.mp4.json
# Doing data/haarlem/2020/transcripts/764339.mp4.json
# Doing data/haarlem/2020/transcripts/764344.mp4.json
# Doing data/haarlem/2020/transcripts/706582.mp4.json
# Doing data/haarlem/2020/transcripts/706566.mp4.json
# Doing data/haarlem/2020/transcripts/937749.mp4.json
# Doing data/haarlem/2020/transcripts/764358.mp4.json
# Doing data/haarlem/2020/transcripts/706545.mp4.json
# Doing data/haarlem/2020/transcripts/730221.mp4.json
# Doing data/haarlem/2020/transcripts/736992.mp4.json
# Doing data/haarlem/2020/transcripts/764352.mp4.json
# Doing data/haarlem/2020/transcripts/706570.mp4.json
# Doing data/haarlem/2020/transcripts/706538.mp4.json
# Doing data/haarlem/2020/transcripts/745509.mp4.json
# Doing data/haarlem/2020/transcripts/706491.mp4.json
# Doing data/haarlem/2020/transcripts/706543.mp4.json
# Doing data/haarlem/2020/transcripts/779582.mp4.json
# Doing data/haarlem/2020/transcripts/764355.mp4.json
# Doing data/haarlem/2020/transcripts/764354.mp4.json
# Doing data/haarlem/2020/transcripts/706593.mp4.json
# Doing data/haarlem/2020/transcripts/706592.mp4.json
# Doing data/haarlem/2020/transcripts/706555.mp4.json
# Doing data/haarlem/2020/transcripts/706585.mp4.json
# Doing data/haarlem/2020/transcripts/740344.mp4.json
# Doing data/haarlem/2020/transcripts/764335.mp4.json
# Doing data/haarlem/2020/transcripts/764334.mp4.json
# Doing data/haarlem/2020/transcripts/706560.mp4.json
# Doing data/haarlem/2018/transcripts/454573.mp4.json
# Doing data/haarlem/2018/transcripts/454527.mp4.json
# Doing data/haarlem/2018/transcripts/454580.mp4.json
# Doing data/haarlem/2018/transcripts/540837.mp4.json
# Doing data/haarlem/2018/transcripts/454574.mp4.json
# Doing data/haarlem/2018/transcripts/518435.mp4.json
# Doing data/haarlem/2018/transcripts/518419.mp4.json
# Doing data/haarlem/2018/transcripts/506778.mp4.json
# Doing data/haarlem/2018/transcripts/518427.mp4.json
# Doing data/haarlem/2018/transcripts/518412.mp4.json
# Doing data/haarlem/2018/transcripts/518446.mp4.json
# Doing data/haarlem/2018/transcripts/518430.mp4.json
# Doing data/haarlem/2018/transcripts/512403.mp4.json
# Doing data/haarlem/2018/transcripts/518441.mp4.json
# Doing data/haarlem/2018/transcripts/518437.mp4.json
# Doing data/haarlem/2018/transcripts/512404.mp4.json
# Doing data/haarlem/2016/transcripts/246550.mp4.json
# diorization file for  not found.
# Doing data/haarlem/2016/transcripts/246547.mp4.json
# Doing data/haarlem/2016/transcripts/246546.mp4.json
# Doing data/haarlem/2016/transcripts/246562.mp4.json
# Doing data/haarlem/2016/transcripts/291061.mp4.json
# Doing data/haarlem/2016/transcripts/246557.mp4.json
# Doing data/haarlem/2016/transcripts/246556.mp4.json
# Doing data/haarlem/2016/transcripts/246545.mp4.json
# Doing data/haarlem/2016/transcripts/246636.mp4.json
# Doing data/haarlem/2016/transcripts/246555.mp4.json
# Doing data/haarlem/2016/transcripts/246561.mp4.json
# Doing data/haarlem/2016/transcripts/246543.mp4.json
# Doing data/haarlem/2016/transcripts/246542.mp4.json
# Doing data/haarlem/2016/transcripts/274115.mp4.json
# Doing data/haarlem/2016/transcripts/246548.mp4.json
