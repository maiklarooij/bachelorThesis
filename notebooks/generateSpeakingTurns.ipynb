# %%
import json
import os

# %%
government = 'ridderkerk'
BASE_PATH = f"/Volumes/Samsung_T5/data/{government}/vergaderingen"

# %%
def load_transcript(path):
    with open(path, "r") as f:
        data = json.load(f)

    data = [
        {
            "start": l["start"],
            "end": l["end"],
            "text": l["text"].replace("...", "").strip(),
        }
        for l in data["segments"]
    ]

    return data


def load_diorizations(path):
    with open(path, "r") as f:
        lines = f.readlines()
        data = [
            {"start": float(rttm[3]), "duration": float(rttm[4]), "speaker": rttm[7]}
            for rttm in [line.strip().split(" ") for line in lines]
        ]

    return data

# %%
def create_speaking_turns(diorizations):
    current_speaker = ""
    current_speaker_start = 0
    current_speaker_duration = 0

    speaking_turns = []

    for i, dior in enumerate(diorizations):
        # If speaker speaks for less than a few seconds, and they do not keep speaking,
        # it is probably a diorization error and we discard it.
        if (
            i < len(diorizations) - 2
            and dior["duration"] < 1
            and dior["speaker"] != diorizations[i + 1]["speaker"]
        ):
            current_speaker_duration = (
                dior["start"] + dior["duration"] - current_speaker_start
            )
            continue
        if dior["speaker"] == current_speaker:
            current_speaker_duration = (
                dior["start"] + dior["duration"] - current_speaker_start
            )
        else:
            # TODO: handle
            if i != 0:
                speaking_turns.append(
                    {
                        "speaker": current_speaker,
                        "start": round(current_speaker_start, 2),
                        "duration": round(current_speaker_duration, 2),
                    }
                )

            current_speaker = dior["speaker"]
            current_speaker_start = dior["start"]
            current_speaker_duration = dior["duration"]

    return speaking_turns

# %%
def create_speakers_text(
    speaking_turns, transcript, code, year, government, meeting_type
):
    speakers_text = []
    current_speaker_text = ""
    for speaker in speaking_turns:
        speaker_start = round(speaker["start"], 2)
        speaker_end = round(speaker["start"] + speaker["duration"], 2)
        for i, sentence in enumerate(transcript):
            # If the end of the sentence is further than the speaker's end,
            # speaker is done with talking and his text is added to the list.
            if sentence["start"] < speaker["start"]:
                continue
            if sentence["end"] > speaker_end - 3:
                if current_speaker_text != "":
                    # Prevents some sentences from not being caught due to beginnen
                    # and end rounding errors.
                    if i < len(transcript) - 2:
                        current_speaker_text += " " + (
                            transcript[i + 1]["text"] + transcript[i + 2]["text"]
                        )
                    speakers_text.append(
                        {
                            "text": current_speaker_text,
                            "start": speaker_start,
                            "end": speaker_end,
                            "code": code,
                            "year": year,
                            "government": government,
                            "type": meeting_type,
                            "speaker": speaker["speaker"],
                        }
                    )
                current_speaker_text = ""
                break
            else:
                current_speaker_text += " " + sentence["text"]

    return speakers_text

# %%
def insert_no_speaks(speakers_text):
    speakers_text_with_no_speaks = []
    prev_end = 0
    for speaker in speakers_text:
        curr_start = speaker["start"]
        if curr_start > prev_end:
            speakers_text_with_no_speaks.append(
                {
                    "text": "",
                    "start": prev_end,
                    "end": curr_start,
                    "code": code,
                    "year": year,
                    "government": government,
                    "type": meeting_type,
                    "speaker": "",
                }
            )
            speakers_text_with_no_speaks.append(speaker)

        prev_end = speaker["end"]

    return speakers_text_with_no_speaks

# %%
meeting_type = "vergadering"
for year in os.listdir(BASE_PATH):
    if year == ".DS_Store":
        continue
    if not os.path.isdir(f"{BASE_PATH}/{year}/transcripts") or not os.path.isdir(
        f"{BASE_PATH}/{year}/diorizations"
    ):
        continue

    save_dir = f"{BASE_PATH}/{year}/turnObjects"
    if not os.path.isdir(save_dir):
        os.mkdir(save_dir)

    for transcript_file in os.listdir(f"{BASE_PATH}/{year}/transcripts"):
        if transcript_file.startswith("."):
            continue
        if os.path.isfile(f"{save_dir}/{transcript_file}"):
            print(f"{save_dir}/{transcript_file} already exists")
            continue
        code = transcript_file.split(".")[0]
        if not os.path.isfile(f"{BASE_PATH}/{year}/diorizations/{code}.wav.rttm"):
            print(f"diorization file for {code} not found.")
            continue

        diorizations = load_diorizations(
            f"{BASE_PATH}/{year}/diorizations/{code}.wav.rttm"
        )

        print(f"Doing {BASE_PATH}/{year}/transcripts/{transcript_file}")
        try:
            transcript = load_transcript(
                f"{BASE_PATH}/{year}/transcripts/{transcript_file}"
            )
        except Exception:
            continue
        speaking_turns = create_speaking_turns(diorizations)

        speakers_text = create_speakers_text(
            speaking_turns, transcript, code, year, government, meeting_type
        )

        speakers_text_nospeaks = insert_no_speaks(speakers_text)

        with open(f"{save_dir}/{transcript_file}", "w") as f:
            json.dump(speakers_text_nospeaks, f)
# Out:
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2010/transcripts/117339.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2010/transcripts/117344.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2010/transcripts/117348.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2010/transcripts/117343.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2010/transcripts/117341.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2010/transcripts/117340.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2011/transcripts/117366.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2011/transcripts/117359.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2011/transcripts/117352.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2011/transcripts/117353.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2011/transcripts/117349.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2011/transcripts/117355.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2011/transcripts/117354.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2011/transcripts/117347.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2011/transcripts/117351.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2011/transcripts/117350.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2011/transcripts/117364.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2011/transcripts/117356.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2011/transcripts/117357.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2011/transcripts/117362.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2012/transcripts/117388.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2012/transcripts/117726.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2012/transcripts/117400.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2012/transcripts/117401.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2012/transcripts/117393.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2012/transcripts/117392.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2012/transcripts/117399.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2012/transcripts/117398.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2012/transcripts/117384.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2012/transcripts/117725.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2012/transcripts/117381.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2012/transcripts/115863.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2012/transcripts/117386.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2012/transcripts/117405.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2012/transcripts/117374.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2013/transcripts/53577.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2013/transcripts/56752.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2013/transcripts/21791.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2013/transcripts/22134.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2013/transcripts/21868.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2013/transcripts/39848.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2013/transcripts/42775.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2013/transcripts/47051.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2013/transcripts/56541.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2013/transcripts/21755.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2013/transcripts/51066.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2013/transcripts/43145.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2013/transcripts/47052.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2013/transcripts/21987.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2014/transcripts/59181.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2014/transcripts/65227.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2014/transcripts/100481.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2014/transcripts/74109.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2014/transcripts/69827.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2014/transcripts/126563.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2014/transcripts/139849.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2014/transcripts/135109.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2014/transcripts/62881.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2014/transcripts/70415.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2014/transcripts/73582.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2014/transcripts/100483.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2014/transcripts/100484.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2014/transcripts/65228.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2015/transcripts/153158.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2015/transcripts/153167.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2015/transcripts/185107.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2015/transcripts/167256.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2015/transcripts/153160.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2015/transcripts/153161.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2015/transcripts/153155.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2015/transcripts/226582.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2015/transcripts/153164.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2015/transcripts/153165.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2015/transcripts/153157.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2015/transcripts/153156.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2015/transcripts/153168.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2015/transcripts/153163.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2015/transcripts/153162.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2015/transcripts/236121.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2016/transcripts/249015.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2016/transcripts/294511.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2016/transcripts/305610.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2016/transcripts/274702.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2016/transcripts/300075.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2016/transcripts/249002.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2016/transcripts/248969.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2016/transcripts/248957.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2016/transcripts/249008.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2016/transcripts/249009.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2016/transcripts/248102.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2016/transcripts/249005.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2016/transcripts/268764.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2016/transcripts/248965.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2016/transcripts/249018.mp4.json
# Doing /Volumes/Samsung_T5/data/ridderkerk/vergaderingen/2016/transcripts/