# %%
import os
import re
import requests
import urllib
import json

from bs4 import BeautifulSoup

# %%
# scrapes all hrefs on a page. Returns a set to prevent duplicate hrefs.
def get_hrefs(url):
    r = requests.get(url)
    bsObj = BeautifulSoup(r.content, "html.parser")

    final_links = {link.get("href") for link in bsObj.find_all("a")}

    return final_links

def decode_href(href):
    decoded = bytes(href, "utf-8").decode("unicode_escape")
    # Replace escaped slashes and remove begin and end quotes.
    decoded = decoded.replace("\\/", "/")[1:-1]
    # Some vergaderingen are duplicated due to this anchor tag,
    # I remove the tag so the duplicate vergadering is filtered.
    decoded = decoded.split("#ai")[0]

    return decoded


def save_hrefs(hrefs, year):
    if not os.path.isdir(f"data/haarlem/vergaderingen/{year}"):
        os.mkdir(f"data/haarlem/vergaderingen/{year}")

    with open(f"data/haarlem/vergaderingen/{year}/vergaderingen.txt", "w") as vergaderingen_f:
        with open(f"data/haarlem/vergaderingen/{year}/documenten.txt", "w") as documenten_f:
            with open(f"data/haarlem/vergaderingen/{year}/modules.txt", "w") as modules_f:
                with open(f"data/haarlem/vergaderingen/{year}/rest.txt", "w") as rest_f:
                    for href in hrefs:
                        if "vergadering" in href:
                            vergaderingen_f.write(href + "\n")
                        elif "document" in href:
                            documenten_f.write(href + "\n")
                        elif "module" in href:
                            modules_f.write(href + "\n")
                        else:
                            rest_f.write(href + "\n")

# %%
if not os.path.isdir("data"):
    os.mkdir("data")
if not os.path.isdir("data/haarlem"):
    os.mkdir("data/haarlem")

years = range(2014, 2025)
for year in years:
    if os.path.isdir(f"data/haarlem/vergaderingen/{year}/vergaderingen.txt") or os.path.isdir(f"data/haarlem/{year}/documenten.txt") or os.path.isdir(f"data/haarlem/{year}/modules.txt") or os.path.isdir(f"data/haarlem/{year}/rest.txt"):
        print(f"year {year} already scraped.")
        continue


    all_hrefs_year = set()
    for page in range(1, 30):
        BASE_URL = f"https://gemeentebestuur-haarlem.notubiz.nl/zoeken/result?keywords=vragenuur&limit=25&document_type=&search=send&filter[organisations][]=544&page={page}&filter[date][]={year}"
        all_hrefs_year.update(get_hrefs(BASE_URL))

    # Decode strings and remove duplicates.
    all_hrefs_year = set(list(map(decode_href, all_hrefs_year)))

    print(f"Got data for {year}, total links: {len(all_hrefs_year)}")
    save_hrefs(all_hrefs_year, year)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/personal/Desktop/scriptie/notebooks/haarlemCrawler.ipynb Cell 3 line 1
#      <a href='vscode-notebook-cell:/Users/personal/Desktop/scriptie/notebooks/haarlemCrawler.ipynb#W2sZmlsZQ%3D%3D?line=13'>14</a> for page in range(1, 30):
#      <a href='vscode-notebook-cell:/Users/personal/Desktop/scriptie/notebooks/haarlemCrawler.ipynb#W2sZmlsZQ%3D%3D?line=14'>15</a>     BASE_URL = f"https://gemeentebestuur-haarlem.notubiz.nl/zoeken/result?keywords=vragenuur&limit=25&document_type=&search=send&filter[organisations][]=544&page={page}&filter[date][]={year}"
# ---> <a href='vscode-notebook-cell:/Users/personal/Desktop/scriptie/notebooks/haarlemCrawler.ipynb#W2sZmlsZQ%3D%3D?line=15'>16</a>     all_hrefs_year.update(get_hrefs(BASE_URL))
#      <a href='vscode-notebook-cell:/Users/personal/Desktop/scriptie/notebooks/haarlemCrawler.ipynb#W2sZmlsZQ%3D%3D?line=17'>18</a> # Decode strings and remove duplicates.
#      <a href='vscode-notebook-cell:/Users/personal/Desktop/scriptie/notebooks/haarlemCrawler.ipynb#W2sZmlsZQ%3D%3D?line=18'>19</a> all_hrefs_year = set(list(map(decode_href, all_hrefs_year)))
#
# /Users/personal/Desktop/scriptie/notebooks/haarlemCrawler.ipynb Cell 3 line 3
#       <a href='vscode-notebook-cell:/Users/personal/Desktop/scriptie/notebooks/haarlemCrawler.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> def get_hrefs(url):
# ----> <a href='vscode-notebook-cell:/Users/personal/Desktop/scriptie/notebooks/haarlemCrawler.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a>     r = requests.get(url)
#       <a href='vscode-notebook-cell:/Users/personal/Desktop/scriptie/notebooks/haarlemCrawler.ipynb#W2sZmlsZQ%3D%3D?line=3'>4</a>     bsObj = BeautifulSoup(r.content, "html.parser")
#       <a href='vscode-notebook-cell:/Users/personal/Desktop/scriptie/notebooks/haarlemCrawler.ipynb#W2sZmlsZQ%3D%3D?line=5'>6</a>     final_links = {link.get("href") for link in bsObj.find_all("a")}
#
# File ~/miniconda3/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/miniconda3/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/miniconda3/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/miniconda3/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/miniconda3/lib/python3.11/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~/miniconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:715, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     712     self._prepare_proxy(conn)
#     714 # Make the request on the httplib connection object.
# --> 715 httplib_response = self._make_request(
#     716     conn,
#     717     method,
#     718     url,
#     719     timeout=timeout_obj,
#     720     body=body,
#     721     headers=headers,
#     722     chunked=chunked,
#     723 )
#     725 # If we're going to release the connection in ``finally:``, then
#     726 # the response doesn't need to know about the connection. Otherwise
#     727 # it will also try to release it and we'll have a double-release
#     728 # mess.
#     729 response_conn = conn if not release_conn else None
#
# File ~/miniconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     462             httplib_response = conn.getresponse()
#     463         except BaseException as e:
#     464             # Remove the TypeError from the exception chain in
#     465             # Python 3 (including for exceptions like SystemExit).
#     466             # Otherwise it looks like a bug in the code.
# --> 467             six.raise_from(e, None)
#     468 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     469     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/miniconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:462, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     459 except TypeError:
#     460     # Python 3
#     461     try:
# --> 462         httplib_response = conn.getresponse()
#     463     except BaseException as e:
#     464         # Remove the TypeError from the exception chain in
#     465         # Python 3 (including for exceptions like SystemExit).
#     466         # Otherwise it looks like a bug in the code.
#     467         six.raise_from(e, None)
#
# File ~/miniconda3/lib/python3.11/http/client.py:1390, in HTTPConnection.getresponse(self)
#    1388 try:
#    1389     try:
# -> 1390         response.begin()
#    1391     except ConnectionError:
#    1392         self.close()
#
# File ~/miniconda3/lib/python3.11/http/client.py:325, in HTTPResponse.begin(self)
#     323 # read until we get a non-100 response
#     324 while True:
# --> 325     version, status, reason = self._read_status()
#     326     if status != CONTINUE:
#     327         break
#
# File ~/miniconda3/lib/python3.11/http/client.py:286, in HTTPResponse._read_status(self)
#     285 def _read_status(self):
# --> 286     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     287     if len(line) > _MAXLINE:
#     288         raise LineTooLong("status line")
#
# File ~/miniconda3/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File ~/miniconda3/lib/python3.11/ssl.py:1314, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1310     if flags != 0:
#    1311         raise ValueError(
#    1312           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1313           self.__class__)
# -> 1314     return self.read(nbytes, buffer)
#    1315 else:
#    1316     return super().recv_into(buffer, nbytes, flags)
#
# File ~/miniconda3/lib/python3.11/ssl.py:1166, in SSLSocket.read(self, len, buffer)
#    1164 try:
#    1165     if buffer is not None:
# -> 1166         return self._sslobj.read(len, buffer)
#    1167     else:
#    1168         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
def download_vergadering(url, name):
    # r = requests.get(url)
    # For some reason request.get gave me 500, urllib works fine.
    r = urllib.request.urlopen(url)
    # print(r.status_code, r.reason)
    bsObj = BeautifulSoup(r, "html.parser")
    download_url = bsObj.find(href=re.compile("download"))

    if not download_url:
        return False
    download_url = download_url.get("href")

    try:
        r = requests.get(download_url, stream=True)
        print(f"Downloading {download_url}")
        with open(f"data/haarlem/vergaderingen/{year}/videos/{name}", "wb") as f:
            for chunk in r.iter_content(chunk_size=1024 * 1024):
                if chunk:
                    f.write(chunk)
    except Exception as _:
        return False

    return True

# %%
for year in years:
    if not os.path.isdir(f"data/haarlem/vergaderingen/{year}/videos"):
        os.mkdir(f"data/haarlem/vergaderingen/{year}/videos")
    with open(f"data/haarlem/vergaderingen/{year}/vergaderingen.txt", "r") as vergaderingen_f:
        for url in vergaderingen_f:
            url = url.replace("\n", "")
            code = url.split("/")[-1]
            # extension = download_url.split(".")[-1]
            extension = "mp4"
            name = f"{code}.{extension}"

            if os.path.isfile(f"data/haarlem/vergaderingen/{year}/videos/{name}") or os.path.isfile(
                f"data/haarlem/vergaderingen/{year}/audio/{name}.mp4"
            ) or os.path.isfile(
                f"data/haarlem/vergaderingen/{year}/audio/{name}"):
                print(f"{url} already downloaded.")
                continue

            print(f"Trying {url}")
            if not download_vergadering(url, name):
                with open(f"data/haarlem/vergaderingen/{year}/failed.txt", "a+") as f:
                    f.write(url + "\n")
# Out:
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/148629
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=04.12.14%20Haarlem%20cie-Samenleving.aac
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/101044
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=28.05.14%20Haarlem%20raad.aac
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/101039
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=13.03.14%20Haarlem%20Raad.aac
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/101057
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=27.11.14%20Haarlem%20Raad.aac
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/101663
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=26.03.14%20Haarlem%20gemeenteraad.aac
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/101048
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=03.07.14%20Haarlem%20Raad.aac
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/125416
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=11.09.14%20Haarlem%20raad.aac
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/101045
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=12.06.14%20Haarlem%20raad.aac
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/101041
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=10.04.14%20Haarlem%20raad.aac
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/101042
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=24.04.14%20Haarlem%20Raad.aac
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/101051
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=30.10.14%20Haarlem%20raad.aac
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/101037
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=23.01.14%20Haarlem%20Raad.aac
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/101043
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=15.05.14%20Haarlem%20raad.aac
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/103253
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=13.02.14%20Haarlem%20Raad.aac
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/101050
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=02.10.14%20Haarlem%20raad.aac
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/101058
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=18.12.14%20Haarlem%20Raad.aac
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/146949
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=13.05.15%20Haarlem%20cie%20Bestuur.aac
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/146906
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=15.01.15%20Haarlem%20cie-Samenleving.aac
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/147027
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=03.12.15%20Haarlem%20cie%20Beheer.aac
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/147026
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=17.12.15%20Haarlem%20Raad.aac
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/146965
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=18.06.15%20Haarlem%20cie-Bestuur.aac
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/179327
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=17.06.15%20Haarlem%20cie-Bestuur.aac
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/1105108
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/146998
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=01.10.15%20Haarlem%20raad.aac
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/149093
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=02.07.15%20Haarlem%20raad.aac
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/146930
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=23.04.15%20Haarlem%20raad.aac
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/235351
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/146971
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=27.08.15%20Haarlem%20cie-Bestuur.aac
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/146933
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=09.04.15%20Haarlem%20cie-Bestuur.aac
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/146921
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=12.03.15%20Haarlem%20Raad.aac
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/146961
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=04.06.15%20Haarlem%20cie-bestuur.aac
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/146929
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=02.04.15%20Haarlem%20Raad%20NIEUW.aac
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/146908
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=12.02.15%20Haarlem%20Raad.aac
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/146956
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=11.06.15%20Haarlem%20raad.aac
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/146999
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=29.10.15%20Haarlem%20raad.aac
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/146948
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=28.05.15%20Haarlem%20cie-Bestuur.aac
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/146887
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=22.01.15%20Haarlem%20Raad.aac
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/146942
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=21.05.15%20Haarlem%20Raad.aac
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/1066559
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/246542
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=21.01.16%20Haarlem%20raad.aac
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/246545
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=10.03.16%20Haarlem%20Raad.aac
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/291061
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=12.05.16%20Haarlem%20cie%20Ontwikkeling.aac
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/246556
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=22.09.16%20Haarlem%20raad_CF.mp4
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/246550
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=16.06.16%20Haarlem%20raad.aac
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/246561
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=S_17.11.16_NC_Haarlem_Gemeenteraad.mp4
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/246548
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=26.05.16%20Haarlem%20raad.aac
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/246562
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=S_15.12.16_NC_Haarlem_Gemeenteraad.mp4
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/246636
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=03.11.16%20Haarlem%20cie%20Bestuur.mp4
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/274115
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=14.04.16%20Haarlem%20cie%20Ontwikkeling.aac
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/246557
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=S_13.10.2016_HAARLEM_RAAD.mp4
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/246547
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=21.04.16%20Haarlem%20Raad.aac
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/246555
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=14.07.16%20Haarlem%20Raad.aac
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/246546
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=31.03.16%20Haarlem%20raad.aac
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/246543
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=11.02.16%20Haarlem%20raad.aac
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/374675
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=S_11.05.2017_NC_HAARLEM_gemeenteraad.mp4
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/374681
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=20.07.17%20Haarlem%20Raad.mp4
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/374673
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=S_16.03.17_NC_Haarlem_Raad.mp4
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/380631
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=14.09.17%20Haarlem%20Cie%20Beheer.mp4
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/374676
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=S
20%20Haarlem%20Vragenuur.mp4
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/764357
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=26.11.20%20Haarlem%20Vragenuur.mp4
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/706593
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=17.12.20%20Haarlem%20Raad.mp4
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/764334
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=27.08.20%20Haarlem%20vragenuur%20NO.mp4
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/738846
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=13.05.20%20Haarlem%20raad.mp4
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/706540
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=20.05.20%20Haarlem%20Cie%20Ontwikkeling.mp4
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/706570
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=29.10.20%20Haarlem%20cie%20Ontwikkeling.mp4
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/730238
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=15.04.20%20Haarlem%20Cie%20Bestuur.mp4
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/1075649
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/706581
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=12.11.20%20Haarlem%20Cie%20Beheer.mp4
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/764381
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=04.06.20%20Haarlem%20Vragenuur.mp4
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/721132
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=27.02.20%20Haarlem%20Vragenuur%20NO.mp4
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/706592
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=10.12.20%20Haarlem%20Cie%20Bestuur.mp4
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/742074
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=20.05.20%20Haarlem%20Cie%20Samenleving.mp4
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/706515
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=26.03.20%20Haarlem%20Raad.aac
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/706485
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=30.01.20%20Haarlem%20Raad.mp4
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/764335
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=17.09.20%20Haarlem%20vragenhalfuurtje.mp4
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/706591
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=10.12.20%20Haarlem%20Cie%20Beheer.mp4
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/780852
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=08.10.20%20Haarlem%20cieBestuur.mp4
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/779582
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=01.10.20%20Haarlem%20cieBeheer.mp4
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/764352
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=10.12.20%20Haarlem%20Vragenuur.mp4
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/800767
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=01.12.20%20Haarlem%20cie%20Bestuur.mp4
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/706568
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=17.09.20%20Haarlem%20raad.mp4
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/706574
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/706560
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=27.08.20%20Haarlem%20cie%20Ontwikkeling%20v2.mp4
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/706564
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=24.09.20%20Haarlem%20cie%20SL.mp4
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/764346
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=29.10.20%20Haarlem%20Vragenuur.mp4
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/745507
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=18.06.20%20Haarlem%20cie%20Beheer.mp4
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/706559
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/730691
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=16.04.20%20Haarlem%20Vragenuur.mp4
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/706512
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=12.03.20%20Haarlem%20cie%20Bestuur.mp4
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/706578
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=22.10.20%20Haarlem%20Raad.mp4
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/764344
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=22.10.20%20Haarlem%20Vragenuur.mp4
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/745509
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=18.06.20%20Haarlem%20cie%20Bestuur.mp4
# Trying https://gemeentebestuur-haarlem.notubiz.nl/vergadering/736992
# Downloading https://gemeentebestuur-haarlem.notubiz.nl/media/download?file=14.05.20%20Haarlem%20cie%20Bestuur.mp4
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# OSError: [Errno 28] No space left on device
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# /Users/personal/Desktop/scriptie/notebooks/haarlemCrawler.ipynb Cell 5 line 2
#      <a href='vscode-notebook-cell:/Users/personal/Desktop/scriptie/notebooks/haarlemCrawler.ipynb#W4sZmlsZQ%3D%3D?line=18'>19</a> print(f"Trying {url}")
#      <a href='vscode-notebook-cell:/Users/personal/Desktop/scriptie/notebooks/haarlemCrawler.ipynb#W4sZmlsZQ%3D%3D?line=19'>20</a> if not download_vergadering(url, name):
# ---> <a href='vscode-notebook-cell:/Users/personal/Desktop/scriptie/notebooks/haarlemCrawler.ipynb#W4sZmlsZQ%3D%3D?line=20'>21</a>     with open(f"data/haarlem/vergaderingen/{year}/failed.txt", "a+") as f:
#      <a href='vscode-notebook-cell:/Users/personal/Desktop/scriptie/notebooks/haarlemCrawler.ipynb#W4sZmlsZQ%3D%3D?line=21'>22</a>         f.write(url + "\n")
#
# OSError: [Errno 28] No space left on device

# %%
for year in years:
    if not os.path.isdir(f"data/haarlem/{year}/agendas"):
        os.mkdir(f"data/haarlem/{year}/agendas")
    with open(f"data/haarlem/{year}/vergaderingen.txt", "r") as vergaderingen_f:
        for url in vergaderingen_f:
            url = url.replace("\n", "")
            code = url.replace("\n", "").split("/")[-1]
            output_path = f"data/haarlem/{year}/agendas/{code}.json"
            if os.path.isfile(output_path):
                print(f"{output_path} already exists.")
                continue

            vergadering_json = []
            r = requests.get(url)
            bsObj = BeautifulSoup(r.content, "html.parser")

            agenda_items = [li for li in bsObj.find_all("li", class_="agenda_item")]
            # print(agenda_items)
            for item in agenda_items:
                agenda_point = {}
                btn = item.find("button", class_="item_title")
                if not btn:
                    continue
                span = btn.find("span", class_="item_prefix")

                # Skip sub agenda item (for now, perhaps)
                if not span or not span.text.strip().endswith("."):
                    continue

                agenda = btn.get_text(strip=True)
                agenda_point["agendaPoint"] = agenda
                time_span = item.find("span", class_="item_time")
                if time_span:
                    time = time_span.text.strip().replace("tijdsduur:", "").strip()
                    agenda_point["time"] = time

                vergadering_json.append(agenda_point)

            with open(output_path, "w") as f:
                json.dump(vergadering_json, f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/personal/Desktop/scriptie/notebooks/haarlemCrawler.ipynb Cell 6 line 3
#       <a href='vscode-notebook-cell:/Users/personal/Desktop/scriptie/notebooks/haarlemCrawler.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> for year in years:
#       <a href='vscode-notebook-cell:/Users/personal/Desktop/scriptie/notebooks/haarlemCrawler.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a>     if not os.path.isdir(f"data/haarlem/{year}/agendas"):
# ----> <a href='vscode-notebook-cell:/Users/personal/Desktop/scriptie/notebooks/haarlemCrawler.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a>         os.mkdir(f"data/haarlem/{year}/agendas")
#       <a href='vscode-notebook-cell:/Users/personal/Desktop/scriptie/notebooks/haarlemCrawler.ipynb#W5sZmlsZQ%3D%3D?line=3'>4</a>     with open(f"data/haarlem/{year}/vergaderingen.txt", "r") as vergaderingen_f:
#       <a href='vscode-notebook-cell:/Users/personal/Desktop/scriptie/notebooks/haarlemCrawler.ipynb#W5sZmlsZQ%3D%3D?line=4'>5</a>         for url in vergaderingen_f:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/haarlem/2014/agendas'
