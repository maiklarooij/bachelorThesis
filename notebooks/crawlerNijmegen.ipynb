# %%
import os
import requests

from bs4 import BeautifulSoup

# %%
def maybe_make_dir(name):
    if not os.path.isdir(name):
        os.mkdir(name)


def get_categories(base_url):
    url = "https://nijmegen.bestuurlijkeinformatie.nl/Calendar"
    html = requests.get(url).content
    bsObj = BeautifulSoup(html, "lxml")
    categories = set()

    links = bsObj.findAll("a")
    for link in links:
        if "/Calendar/OpenCategory" in link.attrs["href"]:
            l = link.attrs["href"]
            categories.add(f"{base_url}{l}")

    # return ["100011337"]
    return categories


def get_meeting_urls(base_url, url):
    html = requests.get(url).content
    bsObj = BeautifulSoup(html, "lxml")
    urls = set()

    links = bsObj.findAll("a")
    for link in links:
        if "/Index/" in link.attrs["href"]:
            l = link.attrs["href"]
            urls.add(f"{base_url}{l}")

    return urls

# %%
BASE_URL = "https://nijmegen.bestuurlijkeinformatie.nl"
years = [
    "2010",
    "2011",
    "2012",
    "2013",
    "2014",
    "2015",
    "2016",
    "2017",
    "2018",
    "2019",
    "2020",
    "2021",
    "2022",
    "2023",
    "2024",
]
categories = get_categories(BASE_URL)

for category in categories:
    c = category.split("/")[-1]
    maybe_make_dir(f"data/nijmegen/{c}")
    for year in years:
        # If the file already exists do not
        if os.path.isfile(f"data/nijmegen/{c}/{year}/vergaderingen.txt"):
            continue

        hrefs = get_meeting_urls(
            BASE_URL,
            f"{BASE_URL}/Agenda/RetrieveAgendasForYear?agendatypeId={c}&year={year}",
        )
        # If no vergaderingen, continue to next year.
        if len(hrefs) == 0:
            continue

        maybe_make_dir(f"data/nijmegen/{c}/{year}")

        # Write urls to file.
        with open(f"data/nijmegen/{c}/{year}/vergaderingen.txt", "w") as f:
            for href in hrefs:
                f.write(href + "\n")

        print(f"Got category {c}, year:  {year}, number of meetings: {len(hrefs)}")
# Out:
# Got category 100000842, year:  2013, number of meetings: 42
# Got category 100000842, year:  2014, number of meetings: 120
# Got category 100000842, year:  2015, number of meetings: 115
# Got category 100000842, year:  2016, number of meetings: 105
# Got category 100000842, year:  2017, number of meetings: 52
# Got category 100000842, year:  2018, number of meetings: 9
# Got category 100000842, year:  2024, number of meetings: 19
# Got category 100000013, year:  2018, number of meetings: 10
# Got category 100000013, year:  2019, number of meetings: 12
# Got category 100000013, year:  2020, number of meetings: 12
# Got category 100000013, year:  2021, number of meetings: 12
# Got category 100000013, year:  2022, number of meetings: 12
# Got category 100000013, year:  2023, number of meetings: 12
# Got category 100000013, year:  2024, number of meetings: 4
# Got category 100495945, year:  2022, number of meetings: 1
# Got category 100495945, year:  2023, number of meetings: 3
# Got category 100495945, year:  2024, number of meetings: 1
# Got category 100505573, year:  2022, number of meetings: 2
# Got category 100505573, year:  2023, number of meetings: 2
# Got category 100505573, year:  2024, number of meetings: 2
# Got category 100013287, year:  2013, number of meetings: 40
# Got category 100013287, year:  2014, number of meetings: 4
# Got category 100013287, year:  2017, number of meetings: 8
# Got category 100013287, year:  2018, number of meetings: 1
# Got category 100013287, year:  2019, number of meetings: 10
# Got category 100013287, year:  2020, number of meetings: 2
# Got category 100013287, year:  2021, number of meetings: 1
# Got category 100603189, year:  2023, number of meetings: 1
# Got category 100049396, year:  2018, number of meetings: 2
# Got category 100603183, year:  2023, number of meetings: 1
# Got category 100567078, year:  2023, number of meetings: 1
# Got category 100603188, year:  2023, number of meetings: 1
# Got category 100082005, year:  2019, number of meetings: 8
# Got category 100082005, year:  2020, number of meetings: 8
# Got category 100082005, year:  2021, number of meetings: 8
# Got category 100082005, year:  2022, number of meetings: 9
# Got category 100082005, year:  2023, number of meetings: 8
# Got category 100082005, year:  2024, number of meetings: 9
# Got category 100186871, year:  2013, number of meetings: 17
# Got category 100186871, year:  2014, number of meetings: 3
# Got category 100186871, year:  2018, number of meetings: 5
# Got category 100186871, year:  2020, number of meetings: 8
# Got category 100186871, year:  2021, number of meetings: 16
# Got category 100186871, year:  2022, number of meetings: 16
# Got category 100186871, year:  2023, number of meetings: 20
# Got category 100186871, year:  2024, number of meetings: 7
# Got category 100011982, year:  2013, number of meetings: 18
# Got category 100011982, year:  2016, number of meetings: 2
# Got category 100011982, year:  2017, number of meetings: 19
# Got category 100011982, year:  2018, number of meetings: 13
# Got category 100011982, year:  2019, number of meetings: 19
# Got category 100011982, year:  2020, number of meetings: 8
# Got category 100011982, year:  2021, number of meetings: 5
# Got category 100011982, year:  2022, number of meetings: 1
# Got category 100011982, year:  2023, number of meetings: 1
# Got category 100345716, year:  2021, number of meetings: 3
# Got category 100345716, year:  2022, number of meetings: 5
# Got category 100345716, year:  2023, number of meetings: 6
# Got category 100011959, year:  2013, number of meetings: 17
# Got category 100011959, year:  2014, number of meetings: 3
# Got category 100011959, year:  2015, number of meetings: 1
# Got category 100011959, year:  2016, number of meetings: 1
# Got category 100011959, year:  2017, number of meetings: 18
# Got category 100011959, year:  2018, number of meetings: 20
# Got category 100011959, year:  2019, number of meetings: 22
# Got category 100011959, year:  2020, number of meetings: 18
# Got category 100011959, year:  2021, number of meetings: 20
# Got category 100011959, year:  2022, number of meetings: 16
# Got category 100011959, year:  2023, number of meetings: 18
# Got category 100011959, year:  2024, number of meetings: 6
# Got category 100011337, year:  2013, number of meetings: 10
# Got category 100011337, year:  2014, number of meetings: 1
# Got category 100011337, year:  2015, number of meetings: 1
# Got category 100011337, year:  2016, number of meetings: 1
# Got category 100011337, year:  2017, number of meetings: 18
# Got category 100011337, year:  2018, number of meetings: 16
# Got category 100011337, year:  2019, number of meetings: 20
# Got category 100011337, year:  2020, number of meetings: 18
# Got category 100011337, year:  2021, number of meetings: 18
# Got category 100011337, year:  2022, number of meetings: 15
# Got category 100011337, year:  2023, number of meetings: 17
# Got category 100011337, year:  2024, number of meetings: 3
# Got category 100579940, year:  2023, number of meetings: 1
# Got category 100006350, year:  2017, number of meetings: 7
# Got category 100006350, year:  2018, number of meetings: 43
# Got category 100006350, year:  2019, number of meetings: 42
# Got category 100006350, year:  2020, number of meetings: 44
# Got category 100006350, year:  2021, number of meetings: 50
# Got category 100006350, year:  2022, number of meetings: 53
# Got category 100006350, year:  2023, number of meetings: 45
# Got category 100006350, year:  2024, number of meetings: 13
# Got category 100013617, year:  2018, number of meetings: 3
# Got category 100013617, year:  2019, number of meetings: 6
# Got category 100013617, year:  2020, number of meetings: 8
# Got category 100013617, year:  2021, number of meetings: 3
# Got category 100013617, year:  2022, number of meetings: 7
# Got category 100013617, year:  2023, number of meetings: 6
# Got category 100013617, year:  2024, number of meetings: 1
